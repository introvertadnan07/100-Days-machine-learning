# %%
# !pip install dtreeviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dtreeviz
#   Downloading dtreeviz-2.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting graphviz>=0.9 (from dtreeviz)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pandas in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (2.3.1)
# Requirement already satisfied: numpy in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (3.10.7)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting pytest (from dtreeviz)
#   Downloading pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (0.4.6)
# Collecting iniconfig>=1.0.1 (from pytest->dtreeviz)
#   Downloading iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pluggy<2,>=1.5 (from pytest->dtreeviz)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (2.19.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn->dtreeviz) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn->dtreeviz) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn->dtreeviz) (3.6.0)
# Downloading dtreeviz-2.2.2-py3-none-any.whl (91 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading pytest-9.0.2-py3-none-any.whl (374 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Installing collected packages: colour, pluggy, iniconfig, graphviz, pytest, dtreeviz
#
#    ------ --------------------------------- 1/6 [pluggy]
#    ------ --------------------------------- 1/6 [pluggy]
#    -------------------- ------------------- 3/6 [graphviz]
#    -------------------- ------------------- 3/6 [graphviz]
#    -------------------- ------------------- 3/6 [graphviz]
#    -------------------- ------------------- 3/6 [graphviz]
#    -------------------- ------------------- 3/6 [graphviz]
#    -------------------- ------------------- 3/6 [graphviz]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    -------------------------- ------------- 4/6 [pytest]
#    --------------------------------- ------ 5/6 [dtreeviz]
#    --------------------------------- ------ 5/6 [dtreeviz]
#    --------------------------------- ------ 5/6 [dtreeviz]
#    --------------------------------- ------ 5/6 [dtreeviz]
#    --------------------------------- ------ 5/6 [dtreeviz]
#    --------------------------------- ------ 5/6 [dtreeviz]
#    --------------------------------- ------ 5/6 [dtreeviz]
#    ---------------------------------------- 6/6 [dtreeviz]
#
# Successfully installed colour-0.1.5 dtreeviz-2.2.2 graphviz-0.21 iniconfig-2.3.0 pluggy-1.6.0 pytest-9.0.2
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages)
#   WARNING: The scripts py.test.exe and pytest.exe are installed in 'C:\Users\hp\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages)

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import * 
from IPython.display import Image, SVG, display_svg

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
from dtreeviz import model as dtreeviz

# %%
pip install scikit-learn dtreeviz graphviz
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\roaming\python\python313\site-packages (1.7.2)
# Requirement already satisfied: dtreeviz in c:\users\hp\anaconda3\lib\site-packages (2.2.1)
# Requirement already satisfied: graphviz in c:\users\hp\appdata\roaming\python\python313\site-packages (0.21)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (3.10.7)
# Requirement already satisfied: colour in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (9.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (2.19.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plot_tree(
    clas,
    feature_names=iris.feature_names,
    class_names=["setosa", "versicolor", "virginica"],
    filled=True
)
plt.show()

# %% [markdown]
# # 1. Classification

# %%
from sklearn.datasets import fetch_california_housing

boston = fetch_california_housing()

# %%
pip install scikit-learn dtreeviz graphviz
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\roaming\python\python313\site-packages (1.7.2)
# Requirement already satisfied: dtreeviz in c:\users\hp\anaconda3\lib\site-packages (2.2.1)
# Requirement already satisfied: graphviz in c:\users\hp\appdata\roaming\python\python313\site-packages (0.21)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (3.10.7)
# Requirement already satisfied: colour in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\hp\appdata\roaming\python\python313\site-packages (from dtreeviz) (9.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pytest->dtreeviz) (2.19.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages)

# %%
regr = tree.DecisionTreeRegressor(max_depth=1)

from sklearn.datasets import fetch_california_housing
boston = fetch_california_housing()

X_train = boston.data
y_train = boston.target
regr.fit(X_train, y_train)

viz = dtreeviz(
    regr,
    X_train,
    y_train,
    target_name='price',
    feature_names=boston.feature_names
)
viz
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 10
#       7 y_train = boston.target
#       8 regr.fit(X_train, y_train)
# ---> 10 viz = dtreeviz(
#      11     regr,
#      12     X_train,
#      13     y_train,
#      14     target_name='price',
#      15     feature_names=boston.feature_names
#      16 )
#      17 viz
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dtreeviz\trees.py:1914, in model(model, X_train, y_train, tree_index, feature_names, target_name, class_names)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dtreeviz\models\shadow_decision_tree.py:444, in get_shadow_tree(tree_model, X_train, y_train, feature_names, target_name, class_names, tree_index)
#
# ImportError: cannot import name 'sklearn_decision_trees' from 'dtreeviz.models' (C:\Users\hp\AppData\Roaming\Python\Python313\site-packages\dtreeviz\models\__init__.py)

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               scale = 1.5,
               orientation='LR')
viz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 viz = dtreeviz(clas,
#       2                X_train,
#       3                y_train,
#       4                target_name='price',
#       5                feature_names=iris.feature_names,
#       6                class_names=["setosa", "versicolor", "virginica"],
#       7                scale = 1.5,
#       8                orientation='LR')
#       9 viz
#
# TypeError: model() got an unexpected keyword argument 'scale'

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

X = iris.data[np.random.randint(0, len(iris.data)),:]

viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               X=X)
viz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 10
#       6 clas.fit(X_train, y_train)
#       8 X = iris.data[np.random.randint(0, len(iris.data)),:]
# ---> 10 viz = dtreeviz(clas,
#      11                X_train,
#      12                y_train,
#      13                feature_names=iris.feature_names,
#      14                class_names=["setosa", "versicolor", "virginica"],
#      15                X=X)
#      16 viz
#
# TypeError: model() got an unexpected keyword argument 'X'

# %%
X
# Out:
# array([4.9, 3. , 1.4, 0.2])

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               show_node_labels=True)
viz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 viz = dtreeviz(clas,
#       2                X_train,
#       3                y_train,
#       4                target_name='price',
#       5                feature_names=iris.feature_names,
#       6                class_names=["setosa", "versicolor", "virginica"],
#       7                histtype= 'barstacked',
#       8                scale = 1.5,
#       9                orientation='LR',
#      10                show_node_labels=True)
#      11 viz
#
# TypeError: model() got an unexpected keyword argument 'histtype'

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               fancy=False)
viz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 viz = dtreeviz(clas,
#       2                X_train,
#       3                y_train,
#       4                target_name='price',
#       5                feature_names=iris.feature_names,
#       6                class_names=["setosa", "versicolor", "virginica"],
#       7                histtype= 'barstacked',
#       8                scale = 1.5,
#       9                orientation='LR',
#      10                fancy=False)
#      11 viz
#
# TypeError: model() got an unexpected keyword argument 'histtype'

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

X = iris.data[np.random.randint(0, len(iris.data)),:]

viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               X=X,
               show_just_path=True)
viz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 10
#       6 clas.fit(X_train, y_train)
#       8 X = iris.data[np.random.randint(0, len(iris.data)),:]
# ---> 10 viz = dtreeviz(clas,
#      11                X_train,
#      12                y_train,
#      13                target_name='price',
#      14                feature_names=iris.feature_names,
#      15                class_names=["setosa", "versicolor", "virginica"],
#      16                X=X,
#      17                show_just_path=True)
#      18 viz
#
# TypeError: model() got an unexpected keyword argument 'X'

# %%
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="plain_english"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="plain_english"))
#
# NameError: name 'explain_prediction_path' is not defined

# %%
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="sklearn_default"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="sklearn_default"))
#
# NameError: name 'explain_prediction_path' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *

df_cars = pd.read_csv("cars.csv")
X, y = df_cars[['WGT']], df_cars['MPG']

dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

fig = plt.figure()
ax = fig.gca()
rtreeviz_univar(dt, X, y, 'WGT', 'MPG', ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 7
#       4 from dtreeviz.trees import *
#       6 df_cars = pd.read_csv("cars.csv")
# ----> 7 X, y = df_cars[['WGT']], df_cars['MPG']
#       9 dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
#      10 dt.fit(X, y)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['WGT'], dtype='object')] are in the [columns]"

# %%
df_cars = pd.read_csv("cars.csv")

df_cars
# Out:
#         brand  km_driven    fuel                 owner  selling_price
# 0      Maruti     145500  Diesel           First Owner         450000
# 1       Skoda     120000  Diesel          Second Owner         370000
# 2       Honda     140000  Petrol           Third Owner         158000
# 3     Hyundai     127000  Diesel           First Owner         225000
# 4      Maruti     120000  Petrol           First Owner         130000
# ...       ...        ...     ...                   ...            ...
# 8123  Hyundai     110000  Petrol           First Owner         320000
# 8124  Hyundai     119000  Diesel  Fourth & Above Owner         135000
# 8125   Maruti     120000  Diesel           First Owner         382000
# 8126     Tata      25000  Diesel           First Owner         290000
# 8127     Tata      25000  Diesel           First Owner         290000
#
# [8128 rows x 5 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *

# %%
X = df_cars[['brand','fuel']]
y = df_cars['selling_price']

# %%
dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

figsize = (6,5)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111, projection='3d')

t = rtreeviz_bivar_3D(dt,
                      X, y,
                      feature_names=['Vehicle Weight', 'Horse Power'],
                      target_name='MPG',
                      fontsize=14,
                      elev=20,
                      azim=25,
                      dist=8.2,
                      show={'splits','title'},
                      ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[58], line 2
#       1 dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
# ----> 2 dt.fit(X, y)
#       4 figsize = (6,5)
#       5 fig = plt.figure(figsize=figsize)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1358, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1353 partial_fit_and_fitted = (
#    1354     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1355 )
#    1357 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
#    1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:471, in BaseEstimator._validate_params(self)
#     463 def _validate_params(self):
#     464     """Validate types and values of constructor parameters
#     465
#     466     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    469     accepted constraints.
#     470     """
# --> 471     validate_parameter_constraints(
#     472         self._parameter_constraints,
#     473         self.get_params(deep=False),
#     474         caller_name=self.__class__.__name__,
#     475     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'poisson', 'absolute_error', 'friedman_mse'}. Got 'mae' instead.
