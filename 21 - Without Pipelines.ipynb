# %%
import pickle
import numpy as np

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier

ohe_sex = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
ohe_embarked = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
clf = RandomForestClassifier()

# %%
import os
import pickle

os.makedirs('models', exist_ok=True)

pickle.dump(ohe_sex, open('models/ohe_sex.pkl', 'wb'))
pickle.dump(ohe_embarked, open('models/ohe_embarked.pkl', 'wb'))
pickle.dump(clf, open('models/clf.pkl', 'wb'))

# %%
# Assume user input
test_input = np.array([2, 'male', 31.0,0,0,10.5,'5'], dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, '5']], dtype=object)

# %%
test_input_sex = ohe_sex.fit_transform(test_input[:,1].reshape(1,1))

# %%
test_input_sex
# Out:
# array([[1.]])

# %%
test_input_embarked = ohe_embarked.fit_transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# array([[1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_age
# Out:
# array([[31.0]], dtype=object)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 7)

# %%
from sklearn.ensemble import RandomForestClassifier
import pickle
import os

# Example: assuming X_train and y_train exist
clf = RandomForestClassifier()
clf.fit(X_train, y_train)  # Train the model

# Save the trained model
os.makedirs('models', exist_ok=True)
pickle.dump(clf, open('models/clf.pkl', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 7
#       5 # Example: assuming X_train and y_train exist
#       6 clf = RandomForestClassifier()
# ----> 7 clf.fit(X_train, y_train)  # Train the model
#       9 # Save the trained model
#      10 os.makedirs('models', exist_ok=True)
#
# NameError: name 'X_train' is not defined
